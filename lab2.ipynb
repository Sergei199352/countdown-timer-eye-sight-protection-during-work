# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergei199352/rgu/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
df = pd.read_csv("/content/Adevrtising.csv")
#df.head(10)
#print(f"the dataset  has {df.shape[0]} rows and {df.shape[1]} colums")
# sns.set_style("darkgrid")
# sns.pairplot(df, x_vars=["TV", "Radio", "Newspaper"], y_vars = "Sales", height = 5, aspect = 0.7)
